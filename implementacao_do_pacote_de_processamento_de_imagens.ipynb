# %% [markdown]
# # Processamento de imagens utilizando o pacote image-processing-mmc

# %%
#importando módulos e submódulos
from image_processing_mmc.utils import io, plot
from image_processing_mmc.processing import combination, transformation

# %%
#leitura das imagens
image1 = io.read_image(r"C:\Users\Monica\OneDrive\Área de Trabalho\Imagens natureza\image1.jpg")
image2 = io.read_image(r"C:\Users\Monica\OneDrive\Área de Trabalho\Imagens natureza\image2.jpg")

# %%
#exibir as imagens
plot.plot_image(image1)
plot.plot_image(image2)

# %%
#combinação dos histogramas das imagens
result_image = combination.transfer_histogram(image1, image2)
plot.plot_result(image1, image2, result_image)
# Out:
# C:\Users\Monica\anaconda3\lib\site-packages\image_processing_mmc\processing\combination.py:16: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched_image = match_histograms(image1, image2, multichannel=True)
